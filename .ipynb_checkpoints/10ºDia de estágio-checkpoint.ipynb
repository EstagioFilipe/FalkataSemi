# %%
import importlib
import mylib as ml
importlib.reload(ml)
# Out:
# <module 'mylib' from 'C:\\Users\\filipe\\OneDrive - FalkataSemi\\codigo\\mylib.py'>

# %%
ids = ml.getCategories('delfina')

# %%
ml.getProdutos('delfina')
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\filipe\AppData\Local\Temp\ipykernel_58980\1149500911.py", line 1, in <module>
#     ml.getProdutos('delfina')
#   File "C:\Users\filipe\OneDrive - FalkataSemi\codigo\mylib.py", line 67, in getProdutos
#     params["categoryID"] #= ids.index[i]
# KeyError: 'categoryID'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
ids
# Out:
#                  Categoria  CategoriaID
# 0                   Azeite     52030662
# 1                  Bebidas     41008263
# 2                Cafetaria     52017997
# 3                    Carne     57680644
# 4                     Casa     43027531
# 5   Cereais_Pequeno_Almoco     52017633
# 6                  Finados     55112678
# 7                    Fruta     40298495
# 8                  Fumeiro     41092214
# 9          Higiene Pessoal     77568604
# 10                Iogurtes     41062462
# 11              Laticínios     47247435
# 12                 Legumes     40301776
# 13               Mercearia     40502212
# 14                   Natal     56756356
# 15              Pastelaria     46369633
# 16                    Pets     56908570
# 17                  Queijo     40297203
# 18                  Snacks     44287177
# 19                   Vinho     52339749

# %%
df_delfina
# Out:
#            Referencia                                      Nome  Preco  \
# 0       5600712204052                    Azeite Ouro da Fábrica  22.55
# 1          DCA-000150                                    Azeite   5.65
# 2   VAZE1362-22010695                    Azeite Cor do Sol - 5L  18.50
# 3    VAZE939-20110130          Azeite Encostas do Tavora - 2Lts  11.30
# 4    VAZE334-20031610  Azeite Encostas do Távora - Virgem - 5lt  27.00
# ..                ...                                       ...    ...
# 43  VVIN1496-22121539                     Vinho Tinto Udaca 5Lt   8.75
# 44   VVIN805-20073129                      Vinho Tinto Virtuoso   1.15
# 45   VVIN848-20082111                  Vinho Verde Casal Garcia   4.35
# 46   VVIN848-20082194                      Vinho Verde Muralhas   4.75
# 47   VVOD1531-2303169                    Vodka Misss Black 70cl   8.65
#
#    Categoria
# 0     Azeite
# 1     Azeite
# 2     Azeite
# 3     Azeite
# 4     Azeite
# ..       ...
# ...

# %%
ml.getProdutosM('minipreco')
# Out:
# Erro em: 		DIA NA GRELHA Salsichas Churrasco Finas Ervas Embaladas 200 g <s>(9,95 €/Kg.)</s>
# 									(8,95 €/Kg.)
#
# Erro em: 		CAMPOFRIO Fiambre de Peru Fatias Clássicas 90 g <s>(15,56 €/Kg.)</s>
# 									(10,89 €/Kg.)
#
# Erro em: 		RANA Folhas Para Lasanha 250 g <s>(10,76 €/Kg.)</s>
# 									(8,08 €/Kg.)
#
# Erro em: 		LOCTITE Super Cola 3 2 g 1.295,00 €/Kg
# Erro em: 		EXCELLENCE Coloração Castanho Claro N5 1 un <s>(12,99 €/ud.)</s>
# 									(8,44 €/ud.)
#                                                Produto      Price Unidade  \
# 0                       \t\tManga (1 un = 510 g aprox)  2,99 €/Kg    €/Kg
# 1    \t\tHORTA DO DIA Melão Branco (1 un = 2015 g a...  1,99 €/Kg    €/Kg
# 2                        \t\tMaçã Golden Embalada 1 kg  1,59 €/Kg    €/Kg
# 3           \t\tPêssego Paraguaio (1 un = 115 g aprox)  4,89 €/Kg    €/Kg
# 4                 \t\tMaçã Granny (1 un = 200 g aprox)  2,44 €/Kg    €/Kg
# ...

# %%
ml.getProdutosF('delfina')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 ml.getProdutosF('delfina')
#
# AttributeError: module 'mylib' has no attribute 'getProdutosF'
